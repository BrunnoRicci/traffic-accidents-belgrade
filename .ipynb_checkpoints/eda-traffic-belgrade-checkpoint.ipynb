# %%
# %load ../../misc/utils/import.py
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import datetime

from pandas_ods_reader import read_ods

#Display Settings
pw = 16
ph = 9
matplotlib.rcParams['figure.figsize'] = (pw, ph)

#Pandas Dsiplay
pd.options.display.max_rows = 100
pd.options.display.max_columns = 200
pd.options.display.max_colwidth = 200

# import warnings
# warnings.filterwarnings('ignore')

# %%
#Read df
file_name = 'NEZ_OPENDATA_2018_20190125.ods' # year 2018

columns = ['id', 'date', 'long', 'lat', 'acc_outcome' ,'acc_type', 'description']
df = read_ods(file_name, 1, columns=columns)
print("Number of accidents {}".format(len(df)))
# Out:
# Number of accidents 18062

# %%
#Sample
df.sample(5, random_state=23)
# Out:
#               id              date       long        lat     acc_outcome  \
# 16955  1238693.0  12.12.2018,10:00  20.433700  44.794530   Sa mat.stetom
# 1340   1206484.0  30.01.2018,12:05  20.478430  44.810850   Sa mat.stetom
# 11270  1226790.0  23.08.2018,17:45  20.482780  44.731640   Sa mat.stetom
# 11251  1228235.0  23.08.2018,15:00  20.419994  44.821166   Sa mat.stetom
# 5128   1213844.0  16.04.2018,09:50  20.453719  44.800287  Sa povredjenim
#
#                                                  acc_type  \
# 16955                                SN SA JEDNIM VOZILOM
# 1340   SN SA NAJMANjE DVA VOZILA – SKRETANjE ILI PRELAZAK
# 11270                                SN SA JEDNIM VOZILOM
# 11251                           SN SA PARKIRANIM VOZILIMA
# 5128            SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA
#
#                                                                                                           description
# 16955                                                                           Nezgoda sa jednim vozilom na kolovozu
# 1340   Najmanje dva vozila koja se kreću istim putem u istom smeru uz skretanje, skretanje ulevo ispred drugog vozila
# 11270                                      Nezgode sa učešćem jednog vozila na mestu na kome se izvode radovi na putu
# 11251                                                                             Ostali sudari sa parkiranim vozilom
# 5128                                                     Najmanje dva vozila koja se kreću u istom smeru – sustizanje

# %%
#To date-time
df['date'] = pd.to_datetime(df['date'])

df = df.sort_values('date')

# %%
#Check Duplicates
dupl_ids = df[df.duplicated(subset=['id'])]['id']

df.set_index('id').sort_index().loc[dupl_ids].head(4)
# Out:
#                          date       long        lat    acc_outcome  \
# id
# 1231373.0 2018-01-10 14:50:00  20.518139  44.787133  Sa mat.stetom
# 1231373.0 2018-01-10 14:50:00  20.518139  44.787133  Sa mat.stetom
# 1234482.0 2018-01-11 12:05:00  20.466038  44.787856  Sa mat.stetom
# 1234482.0 2018-01-11 12:05:00  20.466038  44.787856  Sa mat.stetom
#
#                                                      acc_type  \
# id
# 1231373.0           SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA
# 1231373.0           SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA
# 1234482.0  SN SA NAJMANjE DVA VOZILA – SKRETANjE ILI PRELAZAK
# 1234482.0  SN SA NAJMANjE DVA VOZILA – SKRETANjE ILI PRELAZAK
#
#                                                                                                                    description
# id
# 1231373.0                                           Najmanje dva vozila koja se kreću u istom smeru – uključivanje u saobraćaj
# 1231373.0                                               Najmanje dva vozila – suprotni smerovi bez skretanja – kretanje unazad
# 1234482.0  Najmanje dva vozila koja se kreću istim putem u istom smeru uz skretanje, polukružno okretanje ispred drugog vozila
# 1234482.0       Najmanje dva vozila koja se kreću istim putem u istom smeru uz skretanje, skretanje ulevo ispred drugog vozila

# %%
#Drop Duplictates
print("Before duplicates removal {}".format(len(df)))
df = df.drop_duplicates(subset=['id'])
print("After duplicates removal {}".format(len(df)))
# Out:
# Before duplicates removal 18062
# After duplicates removal 17956

# %% [markdown]
# ## Accidents Outcomes

# %%
#Plot
order = df['acc_outcome'].value_counts().index

ax = sns.countplot(df['acc_outcome'], order=order, color='#f57542');

ax.set_title('Accident Outcomes Distribution')
plt.xticks(rotation=45);

# %%
df['acc_outcome'].value_counts()
# Out:
# Sa mat.stetom     13179
# Sa povredjenim     4679
# Sa poginulim         98
# Name: acc_outcome, dtype: int64

# %%
df[df['acc_outcome'] == 'Sa poginulim']
# Out:
#               id                date       long        lat   acc_outcome  \
# 514    1204730.0 2018-01-13 04:30:00  20.400860  44.885470  Sa poginulim
# 491    1204899.0 2018-01-13 17:45:00  20.677460  44.411170  Sa poginulim
# 660    1205593.0 2018-01-16 11:10:00  20.476280  44.760950  Sa poginulim
# 729    1205033.0 2018-01-18 02:15:00  20.507840  44.705156  Sa poginulim
# 1123   1205925.0 2018-01-26 21:05:00  20.465750  44.799170  Sa poginulim
# 1405   1206934.0 2018-01-31 22:40:00  20.624370  44.761520  Sa poginulim
# 8897   1221561.0 2018-02-07 15:05:00  20.500200  44.749620  Sa poginulim
# 11748  1227994.0 2018-02-09 04:20:00  20.309187  44.747678  Sa poginulim
# 2013   1207917.0 2018-02-14 07:05:00  20.335430  44.732910  Sa poginulim
# 2435   1209126.0 2018-02-23 10:00:00  20.410830  44.615770  Sa poginulim
# 2499   1208835.0 2018-02-24 06:10:00  20.297123  44.894630  Sa poginulim
# 2514   1208992.0 2018-02-24 15:30:00  20.389930  44.688970  Sa poginulim
# 77     1204151.0 2018-03-01 22:35:00  20.409090  44.819520  Sa poginulim
# 1526   1207600.0 2018-03-02 10:00:00  20.451240  44.856590  Sa poginulim
# 2879   1209564.0 2018-03-03 01:30:00  20.437782  44.931900  Sa poginulim
# 7562   1220083.0 2018-03-06 02:30:00  20.416650  44.838070  Sa poginulim
# 7600   1218723.0 2018-03-06 08:50:00  20.518330  44.885670  Sa poginulim
# 13275  1231191.0 2018-03-10 14:30:00  20.490579  44.819232  Sa poginulim
# 3496   1210751.0 2018-03-15 19:10:00  20.314070  44.692290  Sa poginulim
# 3649   1211231.0 2018-03-18 17:50:00  20.428050  44.792640  Sa poginulim
# 4260   1212496.0 2018-03-30 01:50:00  20.405660  44.775540  Sa poginulim
# 2910   1209693.0 2018-04-03 05:50:00  20.731671  44.663178  Sa poginulim
# 4575   1212908.0 2018-04-04 14:20:00  20.507694  44.686097  Sa poginulim
# 10426  1224820.0 2018-04-08 01:30:00  20.569014  44.708041  Sa poginulim
# 10419  1224782.0 2018-04-08 09:30:00  20.462420  44.814240  Sa poginulim
# 16527  1238540.0 2018-04-12 10:15:00  20.480180  44.817350  Sa poginulim
# 5095   1213778.0 2018-04-15 02:00:00  20.292810  44.493040  Sa poginulim
# 5618   1214834.0 2018-04-25 20:15:00  20.502160  44.739690  Sa poginulim
N SA NAJMANjE DVA VOZILA – SKRETANjE ILI PRELAZAK
# 1123                                       SN SA PEŠACIMA
# 1405                                 SN SA JEDNIM VOZILOM
# 8897   SN SA NAJMANjE DVA VOZILA – SKRETANjE ILI PRELAZAK
# 11748           SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA
# 2013            SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA
# 2435   SN SA NAJMANjE DVA VOZILA – SKRETANjE ILI PRELAZAK
# 2499                                       SN SA PEŠACIMA
# 2514                                       SN SA PEŠACIMA
# 77                                         SN SA PEŠACIMA
# 1526                                 SN SA JEDNIM VOZILOM
# 2879                                       SN SA PEŠACIMA
# 7562                                       SN SA PEŠACIMA
# 7600   SN SA NAJMANjE DVA VOZILA – SKRETANjE ILI PRELAZAK
# 13275  SN SA NAJMANjE DVA VOZILA – SKRETANjE ILI PRELAZAK
# 3496                                       SN SA PEŠACIMA
# 3649            SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA
# 4260            SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA
# 2910                                 SN SA JEDNIM VOZILOM
# 4575            SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA
# 10426                                      SN SA PEŠACIMA
# 10419                                      SN SA PEŠACIMA
# 16527                                      SN SA PEŠACIMA
# 5095                                 SN SA JEDNIM VOZILOM
# 5618                                 SN SA JEDNIM VOZILOM
# 2957                                       SN SA PEŠACIMA
# 9067                                       SN SA PEŠACIMA
# 11895           SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA
# 13434  SN SA NAJMANjE DVA VOZILA – SKRETANjE ILI PRELAZAK
# 6570                                 SN SA JEDNIM VOZILOM
# 6556                                       SN SA PEŠACIMA
# 6653                                       SN SA PEŠACIMA
# 6646                                       SN SA PEŠACIMA
# 6806            SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA
# 6915                                       SN SA PEŠACIMA
# 7059            SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA
# 7170                                       SN SA PEŠACIMA
# 7179                            SN SA PARKIRANIM VOZILIMA
# 207                                  SN SA JEDNIM VOZILOM
# 1602            SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA
# 16653                                      SN SA PEŠACIMA
# 8210                                 SN SA JEDNIM VOZILOM
# 8228            SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA
# 8578                                       SN SA PEŠACIMA
# 8827                                       SN SA PEŠACIMA
# 1679                                 SN SA JEDNIM VOZILOM
# 3099                                 SN SA JEDNIM VOZILOM
# 7802                                       SN SA PEŠACIMA
# 11969                                SN SA JEDNIM VOZILOM
# 13537                                      SN SA PEŠACIMA
# 16700                                      SN SA PEŠACIMA
# 9562            SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA
# 9582                                 SN SA JEDNIM VOZILOM
# 9583   SN SA NAJMANjE DVA VOZILA – SKRETANjE ILI PRELAZAK
# 9559                                 SN SA JEDNIM VOZILOM
# 9748   SN SA NAJMANjE DVA VOZILA – SKRETANjE ILI PRELAZAK
# 9880                                       SN SA PEŠACIMA
# 9997                                       SN SA PEŠACIMA
# 1680                                       SN SA PEŠACIMA
# 13585                                      SN SA PEŠACIMA
# 10762                                      SN SA PEŠACIMA
# 10964                                SN SA JEDNIM VOZILOM
# 11041  SN SA NAJMANjE DVA VOZILA – SKRETANjE ILI PRELAZAK
# 11080  SN SA NAJMANjE DVA VOZILA – SKRETANjE ILI PRELAZAK
# 11366  SN SA NAJMANjE DVA VOZILA – SKRETANjE ILI PRELAZAK
# 11384                                      SN SA PEŠACIMA
# 11639           SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA
# 6256                                       SN SA PEŠACIMA
# 12091                                      SN SA PEŠACIMA
# 12961                                SN SA JEDNIM VOZILOM
# 4804                                 SN SA JEDNIM VOZILOM
# 9325                                       SN SA PEŠACIMA
# 16857  SN SA NAJMANjE DVA VOZILA – SKRETANjE ILI PRELAZAK
# 14320                                      SN SA PEŠACIMA
# 14374  SN SA NAJMANjE DVA VOZILA – SKRETANjE ILI PRELAZAK
# 14616                                SN SA JEDNIM VOZILOM
# 1845                                 SN SA JEDNIM VOZILOM
# 4844                                       SN SA PEŠACIMA
# 15396                                SN SA JEDNIM VOZILOM
# 15402                                      SN SA PEŠACIMA
# 16907           SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA
# 15980  SN SA NAJMANjE DVA VOZILA – SKRETANjE ILI PRELAZAK
# 16272                                SN SA JEDNIM VOZILOM
# 16331                                      SN SA PEŠACIMA
# 1889            SN SA NAJMANjE DVA VOZILA – BEZ SKRETANjA
# 9451                                       SN SA PEŠACIMA
# 13799                                SN SA JEDNIM VOZILOM
# 15421  SN SA NAJMANjE DVA VOZILA – SKRETANjE ILI PRELAZAK
# 16984                                SN SA JEDNIM VOZILOM
# 16949                           SN SA PARKIRANIM VOZILIMA
# 17425                                      SN SA PEŠACIMA
# 17621                                SN SA JEDNIM VOZILOM
# 17762                                      SN SA PEŠACIMA
# 17800                                SN SA JEDNIM VOZILOM
# 17799                                      SN SA PEŠACIMA
#
#                                                                                                                                        description
# 514                                                                                Nezgoda sa jednim vozilom – silazak ulevo sa kolovoza na pravcu
# 491                                                                                   Prelazak pešaka sleva, van raskrsnice , bez skretanja vozila
# 660                                                                                   Prelazak pešaka zdesna, van raskrsnice, bez skretanja vozila
# 729                                    Najmanje dva vozila koja se kreću istim putem u suprotnim smerovima uz skretanje ulevo ispred drugog vozila
# 1123                                                                                  Prelazak pešaka sleva, van raskrsnice , bez skretanja vozila
# 1405                                                          Nezgoda sa jednim vozilom bez prepreka na kolovozu na nepoznat, nespecificiran način
# 8897                                   Najmanje dva vozila koja se kreću istim putem u suprotnim smerovima uz skretanje ulevo ispred drugog vozila
# 11748                                                                                                            Najmanje dva vozila – čeoni sudar
# 2013                                                                                                             Najmanje dva vozila – čeoni sudar
# 2435                                Najmanje dva vozila koja se kreću istim putem u istom smeru uz skretanje, skretanje ulevo ispred drugog vozila
# 2499                                                                                  Prelazak pešaka sleva, van raskrsnice , bez skretanja vozila
# 2514                                                                                 Pešak se kreće duž kolovoza suprotno od smera kretanja vozila
# 77                                                                                                                         Pešak stoji na kolovozu
# 1526                                                                                     Nezgoda sa jednim vozilom – silazak sa kolovoza u krivini
# 2879                                                                                           Pešak se kreće duž kolovoza u smeru kretanja vozila
# 7562                                                                                  Prelazak pešaka zdesna, van raskrsnice, bez skretanja vozila
# 7600   Najmanje dva vozila koja se kreću različitim putevima uz prolazak kroz raskrsnicu, ili od kojih jedno prelazi preko kolovoza, bez skretanja
# 13275  Najmanje dva vozila koja se kreću različitim putevima uz prolazak kroz raskrsnicu, ili od kojih jedno prelazi preko kolovoza, bez skretanja
# 3496                                                                                  Prelazak pešaka zdesna, van raskrsnice, bez skretanja vozila
# 3649                                                                     Ostali sudari sa najmanje dva vozila koja se kreću u istom smeru – ostalo
# 4260                                                                                  Najmanje dva vozila koja se kreću u istom smeru – sustizanje
# 2910                                                                               Nezgoda sa jednim vozilom – silazak ulevo sa kolovoza na pravcu
# 4575                                                                                                             Najmanje dva vozila – čeoni sudar
# 10426                                                                                                                     Pešak – ostale situacije
# 10419                                                                                         Pešak stoji ili se kreće, sa kretanjem vozila unazad
# 16527                                                                            Prelazak pešaka zdesna, sa skretanjem vozila udesno, u raskrsnici
# 5095                                                                              Nezgoda sa jednim vozilom – silazak udesno sa kolovoza na pravcu
# 5618                                                                                     Nezgoda sa jednim vozilom – silazak sa kolovoza u krivini
# 2957                                                                                  Prelazak pešaka sleva, van raskrsnice , bez skretanja vozila
# 9067                                                                                  Prelazak pešaka zdesna, van raskrsnice, bez skretanja vozila
# 11895                                                                                 Najmanje dva vozila koja se kreću u istom smeru – sustizanje
# 13434  Najmanje dva vozila koja se kreću različitim putevima uz prolazak kroz raskrsnicu, ili od kojih jedno prelazi preko kolovoza, bez skretanja
# 6570                                                                                                       Nezgoda sa jednim vozilom i prevrtanjem
# 6556                                                                                  Prelazak pešaka sleva, van raskrsnice , bez skretanja vozila
# 6653                                                                                  Prelazak pešaka sleva, van raskrsnice , bez skretanja vozila
# 6646                                                                                  Prelazak pešaka sleva, van raskrsnice , bez skretanja vozila
# 6806                                                                        Ostale nezgode sa najmanje dva vozila – suprotni smerovi bez skretanja
# 6915                                                                                  Prelazak pešaka zdesna, van raskrsnice, bez skretanja vozila
# 7059                                                                                  Najmanje dva vozila koja se kreću u istom smeru – sustizanje
# 7170                                                                                  Prelazak pešaka sleva, van raskrsnice , bez skretanja vozila
# 7179                                                                                          Sudar sa parkiranim vozilom sa desne strane kolovoza
# 207                                                                               Nezgoda sa jednim vozilom – silazak udesno sa kolovoza na pravcu
# 1602                                                                                                             Najmanje dva vozila – čeoni sudar
# 16653                                                                                 Prelazak pešaka sleva, van raskrsnice , bez skretanja vozila
# 8210                                                                               Nezgoda sa jednim vozilom – silazak ulevo sa kolovoza na pravcu
# 8228                                                                                  Najmanje dva vozila koja se kreću u istom smeru – sustizanje
# 8578                                                                                                                      Pešak – ostale situacije
# 8827                                                                          Prelazak pešaka preko kolovoza, van raskrsnice, bez skretanja vozila
# 1679                                                                              Nezgoda sa jednim vozilom – silazak udesno sa kolovoza na pravcu
# 3099                                                                                                  Nezgode sa učešćem šinskog i drumskog vozila
# 7802                                                                                           Pešak se kreće duž kolovoza u smeru kretanja vozila
# 11969                                                                                                        Nezgoda sa jednim vozilom na kolovozu
# 13537                                                                                 Prelazak pešaka zdesna, van raskrsnice, bez skretanja vozila
# 16700                                                                                 Prelazak pešaka sleva, van raskrsnice , bez skretanja vozila
# 9562                                                                                                             Najmanje dva vozila – čeoni sudar
# 9582                                                                               Nezgoda sa jednim vozilom – silazak ulevo sa kolovoza na pravcu
# 9583   Najmanje dva vozila koja se kreću različitim putevima uz prolazak kroz raskrsnicu, ili od kojih jedno prelazi preko kolovoza, bez skretanja
# 9559                                                                                     Nezgoda sa jednim vozilom – silazak sa kolovoza u krivini
# 9748                                Najmanje dva vozila koja se kreću istim putem u istom smeru uz skretanje, skretanje ulevo ispred drugog vozila
# 9880                                                                                  Prelazak pešaka zdesna, van raskrsnice, bez skretanja vozila
# 9997                                                                                        Pešak zaustavljen na trotoaru ili biciklističkoj stazi
# 1680                                                                                  Prelazak pešaka zdesna, van raskrsnice, bez skretanja vozila
# 13585                                                                                 Prelazak pešaka zdesna, van raskrsnice, bez skretanja vozila
# 10762                                                                             Prelazak pešaka sleva, sa skretanjem vozila udesno, u raskrsnici
# 10964                                                         Nezgoda sa jednim vozilom bez prepreka na kolovozu na nepoznat, nespecificiran način
# 11041                                  Najmanje dva vozila koja se kreću istim putem u suprotnim smerovima uz skretanje ulevo ispred drugog vozila
# 11080                               Najmanje dva vozila koja se kreću istim putem u istom smeru uz skretanje, skretanje ulevo ispred drugog vozila
# 11366                          Najmanje dva vozila koja se kreću istim putem u istom smeru uz skretanje, polukružno okretanje ispred drugog vozila
# 11384                                                                                            Pešak se kreće duž kolovoza ili stoji na kolovozu
# 11639                                                                                 Najmanje dva vozila koja se kreću u istom smeru – preticanje
# 6256                                                                                     Prelazak pešaka sleva, u raskrsnici, bez skretanja vozila
# 12091                                                                                                                     Pešak – ostale situacije
# 12961                                                                              Nezgoda sa jednim vozilom – silazak ulevo sa kolovoza na pravcu
# 4804                                                                                     Nezgoda sa jednim vozilom – silazak sa kolovoza u krivini
# 9325                                                                                     Prelazak pešaka sleva, u raskrsnici, bez skretanja vozila
# 16857  Najmanje dva vozila koja se kreću različitim putevima uz prolazak kroz raskrsnicu, ili od kojih jedno prelazi preko kolovoza, bez skretanja
# 14320                                                                                 Prelazak pešaka sleva, van raskrsnice , bez skretanja vozila
# 14374                                  Najmanje dva vozila koja se kreću istim putem u suprotnim smerovima uz skretanje ulevo ispred drugog vozila
# 14616                                                                             Nezgoda sa jednim vozilom – silazak udesno sa kolovoza na pravcu
# 1845                                                                               Nezgoda sa jednim vozilom – silazak ulevo sa kolovoza na pravcu
# 4844                                                                                  Prelazak pešaka zdesna, van raskrsnice, bez skretanja vozila
# 15396                                                                             Nezgoda sa jednim vozilom – silazak udesno sa kolovoza na pravcu
# 15402                                                                                          Pešak se kreće duž kolovoza u smeru kretanja vozila
# 16907                                                                                                            Najmanje dva vozila – čeoni sudar
# 15980                                  Najmanje dva vozila koja se kreću istim putem u suprotnim smerovima uz skretanje ulevo ispred drugog vozila
# 16272                                                                                    Nezgoda sa jednim vozilom – silazak sa kolovoza u krivini
# 16331                                                                                       Pešak zaustavljen na trotoaru ili biciklističkoj stazi
# 1889                                                            Ostale nezgode sa učešćem najmanje dva vozila bez skretanja (bez podataka o smeru)
# 9451                                                                              Prelazak pešaka sleva, sa skretanjem vozila udesno, u raskrsnici
# 13799                                                                                                        Nezgoda sa jednim vozilom na kolovozu
# 15421  Najmanje dva vozila koja se kreću različitim putevima uz prolazak kroz raskrsnicu, ili od kojih jedno prelazi preko kolovoza, bez skretanja
# 16984                                                                              Nezgoda sa jednim vozilom – silazak ulevo sa kolovoza na pravcu
# 16949                                                                                                          Ostali sudari sa parkiranim vozilom
# 17425                                                                                Pešak se kreće duž kolovoza suprotno od smera kretanja vozila
# 17621                                                                                    Nezgoda sa jednim vozilom – silazak sa kolovoza u krivini
# 17762                                                                                 Prelazak pešaka zdesna, van raskrsnice, bez skretanja vozila
# 17800                                                                                                        Nezgoda sa jednim vozilom na kolovozu
# 17799                                                                                         Pešak stoji ili se kreće, sa kretanjem vozila unazad

# %% [markdown]
# ## Accident Types

# %%
#Plot
order = df['acc_type'].value_counts().index

ax = sns.countplot(df['acc_type'], order=order, color='#32a89b');

ax.set_title('Accident Type Distribution')
plt.xticks(rotation=45);

# %%
#Plot
topl = df[df['acc_outcome'] == 'Sa poginulim']
order = df['acc_type'].value_counts().index

ax = sns.countplot(topl['acc_type'], order=order, color='#eb4c34');

ax.set_title('Accident Type Distribution - Accidents with Casualties')
plt.xticks(rotation=45);

# %% [markdown]
# ## Seasonality of Accidents

# %%
#Seasonal df
ses_df = df.set_index('date')
ses_df['count'] = 1

#Resample
ses_df = ses_df.resample('1m')[['count']].sum()

# %%
#Plot
ax = ses_df.plot();

ax.set_title('Number of Accidents Throughout The Year');

# %%
#Weekday
day_map = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}
df['day_of_week'] = df['date'].dt.dayofweek.map(day_map)

# %%
#Plot
ax = sns.countplot(df['day_of_week'], color='#46d4d1');

ax.set_title('Day Of Week');

# %% [markdown]
# ## GeoLoc

# %%
belgrade_loc = {'lat':'44.7866', 'long':'20.4489'}

# %%
plt.scatter(df['long'], df['lat'], s=[5] * len(df), color='#32a89b');

# %%
from gmplot import gmplot

# %%
#Create Heatmap
gmap = gmplot.GoogleMapPlotter(belgrade_loc['lat'],belgrade_loc['long'], zoom=1);

heatmap = gmap.heatmap(df['lat'], df['long'])

gmap.draw("accidents_heatmap.html")
